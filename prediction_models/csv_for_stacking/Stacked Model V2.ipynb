# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from helper_functions import *

# %%
LR_data = pd.read_csv("./LR_Model_Predictions_(2016-2018).csv", low_memory=False, header=0)
LGBM_data = pd.read_csv("./LGBM_Predictions.csv", low_memory=False, header=0)
LSTM_data = pd.read_csv("./LSTM_predicted.csv", low_memory=False, header=0)
RF_data = pd.read_csv("./RF_predictions.csv", low_memory=False, header=0)

result = LGBM_data.set_index("DATE").join(LSTM_data.set_index("DATE"), on='DATE', lsuffix="_LGBM", rsuffix="_LSTM").reset_index()
result = result.set_index("DATE").join(RF_data.set_index("DATE"), on='DATE').reset_index()
result = result.set_index("DATE").join(LR_data.set_index("DATE"), on='DATE', lsuffix="_RF", rsuffix="_LR").reset_index()

result = result.fillna(method='bfill')
result.to_csv("Stacked_Model_train_xV2.csv", index=False)

# %%
LR_data = pd.read_csv("./LR_Model_Predictions_(2016-2018)v2.csv", low_memory=False, header=0)
LGBM_data = pd.read_csv("./LGBM_Predictionsv2.csv", low_memory=False, header=0)
LSTM_data = pd.read_csv("./LSTM_predictedv2.csv", low_memory=False, header=0)
RF_data = pd.read_csv("./RF_predictionsv2.csv", low_memory=False, header=0)

result2 = LGBM_data.set_index("DATE").join(LSTM_data.set_index("DATE"), on='DATE', lsuffix="_LGBM", rsuffix="_LSTM").reset_index()
result2 = result2.set_index("DATE").join(RF_data.set_index("DATE"), on='DATE').reset_index()
result2 = result2.set_index("DATE").join(LR_data.set_index("DATE"), on='DATE', lsuffix="_RF", rsuffix="_LR").reset_index()

result2 = result2.fillna(method='bfill')
result2.to_csv("Stacked_Model_test_xV2.csv", index=False)

# %%
data2 = pd.read_pickle("data_base_test.pkl")
data2 = data2.fillna(method='bfill')

data3 = pd.read_pickle("data_stack_test.pkl")
data3 = data3.fillna(method='bfill')

# %%
#feature_list_AD = ['F_AD_LGBM', 'F_AD_LSTM', 'F_AD_LR', 'F_AD_RF']
#train_x_AD = result[feature_list_AD]

#train_y_AD = data2['F_AD']['CLOSE']
#train_y_AD = pd.DataFrame(train_y_AD)

#feature_list_AD = ['F_AD_LGBM', 'F_AD_LSTM', 'F_AD_LR', 'F_AD_RF']
#test_x_AD = result2[feature_list_AD]

#test_y_AD = data3['F_AD']['CLOSE']
#test_y_AD = pd.DataFrame(test_y_AD)

#lr = LinearRegression()
#model = lr.fit(train_x_AD, train_y_AD)
#y_pred = lr.predict(test_x_AD)

#coefficient = lr.coef_
#intercept = lr.intercept_
#rmse = rmse_ratio(test_y_AD, y_pred)
#mape = mean_absolute_percentage_error(test_y_AD, y_pred)

#result = pd.DataFrame(coefficient, columns=['1', '2', '3', '4'])
#result['Intercept'] = intercept
#result['RMSE'] = rmse.values
#result['MAPE'] = mape.values
#result['Future'] = 'F_AD'
#result

# %%
#predicted = pd.DataFrame(y_pred, columns=['F_AD'])
#predicted

# %%
futures = ['F_AD','F_AE','F_AH','F_AX','F_BC','F_BG','F_BO','F_BP',
               'F_C','F_CA','F_CC','F_CD','F_CF','F_CL','F_CT','F_DL',             
               'F_DM','F_DT','F_DX','F_DZ','F_EB','F_EC','F_ED','F_ES',
               'F_F','F_FB','F_FC','F_FL','F_FM','F_FP','F_FV','F_FY',             
               'F_GC','F_GD','F_GS','F_GX','F_HG','F_HO','F_HP','F_JY',
              'F_KC','F_LB','F_LC','F_LN','F_LQ','F_LR','F_LU','F_LX',
           'F_MD','F_MP','F_ND','F_NG','F_NQ','F_NR','F_NY','F_O',
             'F_OJ','F_PA','F_PL','F_PQ','F_RB','F_RF','F_RP','F_RR',
               'F_RU','F_RY','F_S','F_SB','F_SF','F_SH','F_SI','F_SM',
             'F_SS','F_SX','F_TR','F_TU','F_TY','F_UB','F_US','F_UZ',
            'F_VF','F_VT','F_VW','F_VX','F_W','F_XX','F_YM','F_ZQ']

# %%
new_features = pd.DataFrame(index=np.arange(len(data3)), columns=np.arange(88))
new_features.columns = futures
new_features["DATE"] = (list(data3.index))
new_features = new_features.set_index("DATE")
new_features
# Out:
#            F_AD F_AE F_AH F_AX F_BC F_BG F_BO F_BP  F_C F_CA ...  F_US F_UZ  \
# DATE                                                         ...
# 2018-01-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-08  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-15  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-16  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-01-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-06  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-07  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-08  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-02-09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ... ...   ...  ...
# 2018-11-20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-11-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-06  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-07  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 2018-12-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#
#            F_VF F_VT F_VW F_VX  F_W F_XX F_YM F_ZQ
# DATE
# 2018-01-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-08  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-15  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-16  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-06  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-07  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-08  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02-09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...
# 2018-11-20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-11-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-06  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-07  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-12-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [261 rows x 88 columns]

# %%
for fut in futures:
    train_y = data2[fut]['CLOSE']
    train_y = pd.DataFrame(train_y)
    test_y = data3[fut]['CLOSE']
    test_y = pd.DataFrame(test_y)
    fut = fut + '_'
    feature_list = []
    for j in result.columns:
        if fut in j:
            feature_list.append(j)
    train_x = result.loc[:,feature_list]
    test_x = result2.loc[:,feature_list]
    lr = LinearRegression()
    model = lr.fit(train_x, train_y)
    y_pred = lr.predict(test_x)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/linear_model/base.py:485: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-65362d9ab453> in <module>()
#      13     lr = LinearRegression()
#      14     model = lr.fit(train_x, train_y)
# ---> 15     y_pred = lr.predict(test_x)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     566         if force_all_finite:
#     567             _assert_all_finite(array,
# --> 568                                allow_nan=force_all_finite == 'allow-nan')
#     569
#     570     shape_repr = _shape_repr(array.shape)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
